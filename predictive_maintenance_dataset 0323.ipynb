# %% [markdown]
# <big>数据读取<big>

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# 基础路径
base_path = Path(r"C:\Users\田\Downloads\新建文件夹\Predictive Maintenance Dataset 2m")  # 你的原始路径

# %%
predictive_maintenance_dataset = pd.read_csv(base_path / 'predictive_maintenance_dataset.csv')

# %% [markdown]
# <big>数据查看<big>

# %%
predictive_maintenance_dataset
# Out:
#              date    device  failure    metric1  metric2  metric3  metric4  \
# 0        1/1/2015  S1F01085        0  215630672       55        0       52
# 1        1/1/2015  S1F0166B        0   61370680        0        3        0
# 2        1/1/2015  S1F01E6Y        0  173295968        0        0        0
# 3        1/1/2015  S1F01JE0        0   79694024        0        0        0
# 4        1/1/2015  S1F01R2B        0  135970480        0        0        0
# ...           ...       ...      ...        ...      ...      ...      ...
# 124489  11/2/2015  Z1F0MA1S        0   18310224        0        0        0
# 124490  11/2/2015  Z1F0Q8RT        0  172556680       96      107        4
# 124491  11/2/2015  Z1F0QK05        0   19029120     4832        0        0
# 124492  11/2/2015  Z1F0QL3N        0  226953408        0        0        0
# 124493  11/2/2015  Z1F0QLC1        0   17572840        0        0        0
#
#         metric5  metric6  metric7  metric8  metric9
# ...

# %%
predictive_maintenance_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124493 entries, 0 to 124493
# Data columns (total 12 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     124493 non-null  object
#  1   device   124493 non-null  object
#  2   failure  124493 non-null  int64
#  3   metric1  124493 non-null  int64
#  4   metric2  124493 non-null  int64
#  5   metric3  124493 non-null  int64
#  6   metric4  124493 non-null  int64
#  7   metric5  124493 non-null  int64
#  8   metric6  124493 non-null  int64
#  9   metric7  124493 non-null  int64
#  10  metric8  124493 non-null  int64
#  11  metric9  124493 non-null  int64
# dtypes: int64(10), object(2)
# memory usage: 12.3+ MB

# %%
predictive_maintenance_dataset.describe()
# Out:
#              failure       metric1        metric2        metric3  \
# count  124494.000000  1.244940e+05  124494.000000  124494.000000
# mean        0.000851  1.223881e+08     159.492706       9.940897
# std         0.029167  7.045933e+07    2179.677781     185.748131
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%         0.000000  6.128476e+07       0.000000       0.000000
# 50%         0.000000  1.227974e+08       0.000000       0.000000
# 75%         0.000000  1.833096e+08       0.000000       0.000000
# max         1.000000  2.441405e+08   64968.000000   24929.000000
#
#              metric4        metric5        metric6        metric7  \
# count  124494.000000  124494.000000  124494.000000  124494.000000
# mean        1.741120      14.222669  260172.657726       0.292528
# std        22.908507      15.943028   99151.078547       7.436924
# min         0.000000       1.000000       8.000000       0.000000
# ...

# %%
predictive_maintenance_dataset.describe(include='object')
# Out:
#             date    device
# count     124494    124494
# unique       304      1169
# top     1/1/2015  Z1F0QLC1
# freq        1163       304

# %%
predictive_maintenance_dataset.isna().sum()
# Out:
# date       0
# device     0
# failure    0
# metric1    0
# metric2    0
# metric3    0
# metric4    0
# metric5    0
# metric6    0
# metric7    0
# metric8    0
# metric9    0
# dtype: int64

# %%
predictive_maintenance_dataset.duplicated().sum()
# Out:
# 1

# %%
predictive_maintenance_dataset.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 124489    False
# 124490    False
# 124491    False
# 124492    False
# 124493    False
# Length: 124494, dtype: bool

# %%
predictive_maintenance_dataset.drop_duplicates(inplace=True)

# %%
predictive_maintenance_dataset.std(numeric_only=True)
# Out:
# failure    2.916737e-02
# metric1    7.045934e+07
# metric2    2.179686e+03
# metric3    1.857489e+02
# metric4    2.290860e+01
# metric5    1.594308e+01
# metric6    9.915139e+04
# metric7    7.436954e+00
# metric8    7.436954e+00
# metric9    2.756623e+02
# dtype: float64

# %%
predictive_maintenance_dataset.var(numeric_only=True)
# Out:
# failure    8.507354e-04
# metric1    4.964518e+15
# metric2    4.751033e+06
# metric3    3.450264e+04
# metric4    5.248039e+02
# metric5    2.541819e+02
# metric6    9.830998e+09
# metric7    5.530828e+01
# metric8    5.530828e+01
# metric9    7.598972e+04
# dtype: float64

# %%
predictive_maintenance_dataset.var(numeric_only=True)
# Out:
# failure    8.507354e-04
# metric1    4.964518e+15
# metric2    4.751033e+06
# metric3    3.450264e+04
# metric4    5.248039e+02
# metric5    2.541819e+02
# metric6    9.830998e+09
# metric7    5.530828e+01
# metric8    5.530828e+01
# metric9    7.598972e+04
# dtype: float64

# %%
predictive_maintenance_dataset.corr(numeric_only=True)
# Out:
#           failure   metric1   metric2   metric3   metric4   metric5   metric6  \
# failure  1.000000  0.001984  0.052901 -0.000949  0.067398  0.002270 -0.000550
# metric1  0.001984  1.000000 -0.004253  0.003702  0.001836 -0.003373 -0.001518
# metric2  0.052901 -0.004253  1.000000 -0.002617  0.146762 -0.013999 -0.026350
# metric3 -0.000949  0.003702 -0.002617  1.000000  0.097452 -0.006697  0.009030
# metric4  0.067398  0.001836  0.146762  0.097452  1.000000 -0.009773  0.024870
# metric5  0.002270 -0.003373 -0.013999 -0.006697 -0.009773  1.000000 -0.017051
# metric6 -0.000550 -0.001518 -0.026350  0.009030  0.024870 -0.017051  1.000000
# metric7  0.119055  0.000151  0.141366 -0.001884  0.045631 -0.009384 -0.012207
# metric8  0.119055  0.000151  0.141366 -0.001884  0.045631 -0.009384 -0.012207
# metric9  0.001066 -0.002256 -0.002049  0.369579  0.024892  0.003591  0.016566
#
#           metric7   metric8   metric9
# failure  0.119055  0.119055  0.001066
# ...

# %% [markdown]
# <big>数据可视化<big>

# %%
predictive_maintenance_dataset.hist(bins=30,figsize=(10,8),)
# Out:
# array([[<Axes: title={'center': 'failure'}>,
#         <Axes: title={'center': 'metric1'}>,
#         <Axes: title={'center': 'metric2'}>],
#        [<Axes: title={'center': 'metric3'}>,
#         <Axes: title={'center': 'metric4'}>,
#         <Axes: title={'center': 'metric5'}>],
#        [<Axes: title={'center': 'metric6'}>,
#         <Axes: title={'center': 'metric7'}>,
#         <Axes: title={'center': 'metric8'}>],
#        [<Axes: title={'center': 'metric9'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
predictive_maintenance_dataset['failure'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric1'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric2'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric3'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric4'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric5'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric6'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric7'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric8'].plot(kind='box')
# Out:
# <Axes: >

# %%
predictive_maintenance_dataset['metric9'].plot(kind='box')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=predictive_maintenance_dataset
n_cols = 2 
n_rows = len(predictive_maintenance_dataset.columns)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 2 * n_rows))
for i, col in enumerate(predictive_maintenance_dataset.columns):
    # Histogram
    sns.histplot(data=df, x=col, kde=True, ax=axes[i, 0], color='skyblue')
    axes[i, 0].set_title(f'{col} - Histogram')

    # Boxplot (horizontal)
    sns.boxplot(data=df, x=col, ax=axes[i, 1], color='lightgreen')
    axes[i, 1].set_title(f'{col} - Boxplot')

plt.tight_layout()
plt.show()

# %%
predictive_maintenance_dataset['failure'].value_counts()
# Out:
# failure
# 0    124387
# 1       106
# Name: count, dtype: int64

# %%
124387/106
# Out:
# 1173.4622641509434

# %% [markdown]
# <big>时间处理<big>

# %%
def date(df):
    df['date'] = pd.to_datetime(df['date'])
    
    # 提取特征
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['day'] = df['date'].dt.day
    df['dayofweek'] = df['date'].dt.dayofweek
    df['is_weekend'] = df['date'].dt.dayofweek.isin([5, 6]).astype(int)
    return df

# %%
predictive_maintenance_dataset
# Out:
#              date    device  failure    metric1  metric2  metric3  metric4  \
# 0        1/1/2015  S1F01085        0  215630672       55        0       52
# 1        1/1/2015  S1F0166B        0   61370680        0        3        0
# 2        1/1/2015  S1F01E6Y        0  173295968        0        0        0
# 3        1/1/2015  S1F01JE0        0   79694024        0        0        0
# 4        1/1/2015  S1F01R2B        0  135970480        0        0        0
# ...           ...       ...      ...        ...      ...      ...      ...
# 124489  11/2/2015  Z1F0MA1S        0   18310224        0        0        0
# 124490  11/2/2015  Z1F0Q8RT        0  172556680       96      107        4
# 124491  11/2/2015  Z1F0QK05        0   19029120     4832        0        0
# 124492  11/2/2015  Z1F0QL3N        0  226953408        0        0        0
# 124493  11/2/2015  Z1F0QLC1        0   17572840        0        0        0
#
#         metric5  metric6  metric7  metric8  metric9
# ...

# %%
predictive_maintenance_dataset=date(predictive_maintenance_dataset)

# %%
predictive_maintenance_dataset.drop(['date'],axis=1,inplace=True)

# %%
predictive_maintenance_dataset.std(numeric_only=True)
# Out:
# device        3.271778e+02
# failure       2.916725e-02
# metric1       7.045933e+07
# metric2       2.179678e+03
# metric3       1.857481e+02
# metric4       2.290851e+01
# metric5       1.594303e+01
# metric6       9.915108e+04
# metric7       7.436924e+00
# metric8       7.436924e+00
# metric9       2.756612e+02
# year          0.000000e+00
# month         2.572167e+00
# day           8.759542e+00
# dayofweek     2.001234e+00
# is_weekend    4.524625e-01
# dtype: float64

# %% [markdown]
# <big>类别处理<big>

# %%
from sklearn.preprocessing import OrdinalEncoder
predictive_maintenance_dataset['device']=OrdinalEncoder().fit_transform(predictive_maintenance_dataset[['device']])

# %%
predictive_maintenance_dataset
# Out:
#         device  failure    metric1  metric2  metric3  metric4  metric5  \
# 0          0.0        0  215630672       55        0       52        6
# 1          2.0        0   61370680        0        3        0        6
# 2          3.0        0  173295968        0        0        0       12
# 3          4.0        0   79694024        0        0        0        6
# 4          5.0        0  135970480        0        0        0       15
# ...        ...      ...        ...      ...      ...      ...      ...
# 124489  1045.0        0   18310224        0        0        0       10
# 124490  1068.0        0  172556680       96      107        4       11
# 124491  1075.0        0   19029120     4832        0        0       11
# 124492  1081.0        0  226953408        0        0        0       12
# 124493  1082.0        0   17572840        0        0        0       10
#
#         metric6  metric7  metric8  metric9  year  month  day  dayofweek  \
# ...

# %%
predictive_maintenance_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124494 entries, 0 to 124493
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   device      124494 non-null  float64
#  1   failure     124494 non-null  int64
#  2   metric1     124494 non-null  int64
#  3   metric2     124494 non-null  int64
#  4   metric3     124494 non-null  int64
#  5   metric4     124494 non-null  int64
#  6   metric5     124494 non-null  int64
#  7   metric6     124494 non-null  int64
#  8   metric7     124494 non-null  int64
#  9   metric8     124494 non-null  int64
#  10  metric9     124494 non-null  int64
#  11  year        124494 non-null  int32
#  12  month       124494 non-null  int32
#  13  day         124494 non-null  int32
#  14  dayofweek   124494 non-null  int32
#  15  is_weekend  124494 non-null  int32
# dtypes: float64(1), int32(5), int64(10)
# memory usage: 12.8 MB

# %% [markdown]
# <big>模型预测<big>

# %%
data=predictive_maintenance_dataset.drop(['failure'],axis=1)
y=predictive_maintenance_dataset[['failure']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2,random_state=42 )

# %%
# %%time

# scikit-learn 模型
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# LightGBM
import lightgbm as lgb

# XGBoost
import xgboost as xgb

# 3. 初始化模型
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, class_weight='balanced',random_state=42),
    "KNN": KNeighborsClassifier(n_neighbors=5),
    "Random Forest": RandomForestClassifier(n_estimators=100,oob_score=True,class_weight='balanced',n_jobs =-1,random_state=42),
    "Decision Tree": DecisionTreeClassifier(max_depth=5,class_weight='balanced', random_state=42),
    "LightGBM": lgb.LGBMClassifier(random_state=42,class_weight='balanced',),
    "XGBoost": xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss',class_weight='balanced', random_state=42),
    "SVM": SVC(probability=True, class_weight='balanced',random_state=42)  # 设置probability=True以计算ROC AUC
}
# Out:
# CPU times: total: 0 ns
# Wall time: 1.02 ms

# %%
import time
from sklearn.metrics import classification_report


 # 训练、预测和评估模型
results = []
training_times = {}

for name, model in models.items():
    start_time = time.time()
    
    # 训练模型
    model.fit(X_train, y_train)
    
    # 记录训练时间
    training_time = time.time() - start_time
    training_times[name] = training_time
    
    # 预测
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None
    
    # 计算评估指标
    report = classification_report(y_test, y_pred)
    print(f'model:{name}')
    print(report)
    print(f'train time:{training_times[name]}\n')
# Out:
# C:\anaconda\envs\py312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# model:Logistic Regression
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     24881
#            1       0.01      0.56      0.02        18
#
#     accuracy                           0.96     24899
#    macro avg       0.51      0.76      0.50     24899
# weighted avg       1.00      0.96      0.98     24899
#
# train time:1.654007911682129
# C:\anaconda\envs\py312\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...
